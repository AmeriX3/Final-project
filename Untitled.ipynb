# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

import requests

# %% [markdown]
# ## Collecting  Data by web scraping

# %%
#driver = webdriver.Chrome(executable_path="chromedriver")
d= requests.get("https://uae.dubizzle.com/motors/used-cars/?page=300").content
UAED = BeautifulSoup(d,"html.parser")
car_model= driver.find_element(By.XPATH,"//*[@id='listings-top']/div/div[1]/div[1]/a/div[2]/div[3]/div[3]")
#car_brand=
#car_price=
#car_odo=
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [64], in <cell line: 4>()
#       2 d= requests.get("https://uae.dubizzle.com/motors/used-cars/?page=300").content
#       3 UAED = BeautifulSoup(d,"html.parser")
# ----> 4 car_model= driver.find_element(By.XPATH,"//*[@id='listings-top']/div/div[1]/div[1]/a/div[2]/div[3]/div[3]")
#
# File ~\anaconda3\envs\ironhack\lib\site-packages\selenium\webdriver\remote\webdriver.py:856, in WebDriver.find_element(self, by, value)
#     853     by = By.CSS_SELECTOR
#     854     value = '[name="%s"]' % value
# --> 856 return self.execute(Command.FIND_ELEMENT, {
#     857     'using': by,
#     858     'value': value})['value']
#
# File ~\anaconda3\envs\ironhack\lib\site-packages\selenium\webdriver\remote\webdriver.py:434, in WebDriver.execute(self, driver_command, params)
# ...

# %%
car_model= driver.find_element(By.XPATH,"//*[@id='listings-top']/div/div[1]/div[1]/a/div[2]/div[3]/div[3]")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 car_model= driver.find_element(By.XPATH,"//*[@id='listings-top']/div/div[1]/div[1]/a/div[2]/div[3]/div[3]")
#
# File ~\anaconda3\envs\ironhack\lib\site-packages\selenium\webdriver\remote\webdriver.py:856, in WebDriver.find_element(self, by, value)
#     853     by = By.CSS_SELECTOR
#     854     value = '[name="%s"]' % value
# --> 856 return self.execute(Command.FIND_ELEMENT, {
#     857     'using': by,
#     858     'value': value})['value']
#
# File ~\anaconda3\envs\ironhack\lib\site-packages\selenium\webdriver\remote\webdriver.py:434, in WebDriver.execute(self, driver_command, params)
#     432 response = self.command_executor.execute(driver_command, params)
#     433 if response:
# --> 434     self.error_handler.check_response(response)
# ...

# %%
car_model= UAED.find_all("div", attrs = ["sc-cmkc2d-7", "sc-12jmuzh-1" ,"cJzZZufJnXmr" ,"heading-text-2"])
car_model
# Out:
# []

# %%
<div data-testid="heading-text-2" class="sc-cmkc2d-7 sc-12jmuzh-1 cJzZZu fJnXmr heading-text-2">Huracan</div>
# Out:
# <html style="height:100%"><head><meta content="NOINDEX, NOFOLLOW" name="ROBOTS"/><meta content="telephone=no" name="format-detection"/><meta content="initial-scale=1.0" name="viewport"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><script async="" src="/We-a-did-and-He-him-as-desir-call-their-Banquo-B"></script></head><body style="margin:0px;height:100%"><iframe frameborder="0" height="100%" id="main-iframe" marginheight="0px" marginwidth="0px" src="/_Incapsula_Resource?SWUDNSAI=31&amp;xinfo=3-12726111-0%202NNN%20RT%281661418698436%2032%29%20q%280%20-1%20-1%20-1%29%20r%280%20-1%29%20B12%2814%2c0%2c0%29%20U18&amp;incident_id=505000830037362312-75296931420116163&amp;edet=12&amp;cinfo=0e000000d6a5&amp;rpinfo=503&amp;cts=TrvpJ8h2G%2blk%2fRlQ%2fm5e6CqJ0s4nG2F2DLAaJXwOBjcZbaR7ngPUD6lbeiQgEHRa&amp;mth=GET" width="100%">Request unsuccessful. Incapsula incident ID: 505000830037362312-75296931420116163</iframe></body></html>

# %%
url = "https://uae.dubizzle.com/motors/used-cars/?page=1"
options = webdriver.ChromeOptions()
driver = webdriver.Chrome()
driver.get(url)
car_model= driver.find_element(By.XPATH,"//*[@id='listings-top']/div/div[1]/div[1]/a/div[2]/div[3]/div[3]")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [66], in <cell line: 5>()
#       3 driver = webdriver.Chrome()
#       4 driver.get(url)
# ----> 5 car_model= driver.find_element(By.XPATH,"//*[@id='listings-top']/div/div[1]/div[1]/a/div[2]/div[3]/div[3]")
#
# File ~\anaconda3\envs\ironhack\lib\site-packages\selenium\webdriver\remote\webdriver.py:856, in WebDriver.find_element(self, by, value)
#     853     by = By.CSS_SELECTOR
#     854     value = '[name="%s"]' % value
# --> 856 return self.execute(Command.FIND_ELEMENT, {
#     857     'using': by,
#     858     'value': value})['value']
#
# File ~\anaconda3\envs\ironhack\lib\site-packages\selenium\webdriver\remote\webdriver.py:434, in WebDriver.execute(self, driver_command, params)
#     432 response = self.command_executor.execute(driver_command, params)
#     433 if response:
# ...

# %%
searchbox = driver.find_element(By.ID, "searchboxinput")
searchbox.send_keys("")
searchbox.send_keys(Keys.RETURN)
time.sleep(5)
restaurant_boxes = driver.find_elements(By.CLASS_NAME, "hfpxzc")
while len(restaurant_boxes)<75:
    scroll_origin = ScrollOrigin.from_element(restaurant_boxes[-1])
    ActionChains(driver).scroll_from_origin(scroll_origin, 0, 1000).perform()
    time.sleep(2)
    last_restaurant = restaurant_boxes[-1]
    restaurant_boxes = driver.find_elements(By.CLASS_NAME, "hfpxzc")
    if last_restaurant == restaurant_boxes[-1]:
        break
for restaurant_box in restaurant_boxes:
    restaurant_box.click()
    time.sleep(5)
    try:
        driver.find_element(By.CLASS_NAME,"DkEaL").click
    except:
        driver.find_element(By.CLASS_NAME,"hh2c6").click
    time.sleep(3)
    big_middle_box = driver.find_elements(By.CLASS_NAME, "PPCwl")
    scroll_origin = ScrollOrigin.from_element(big_middle_box[0])
    ActionChains(driver).scroll_from_origin(scroll_origin, 0, 1000).perform()
    time.sleep(2)
    review_boxes = driver.find_elements(by.CLASS_NAME, "jftiEf.fontBodyMedium")
    while len(review_boxes)<20:
        scroll_origin = ScrollOrigin.from_element(review_boxes[-1])
        ActionChains(driver).scroll_from_origin(scroll_origin, 0, 1000).perform()
        time.sleep(2)
        last_review = review_boxes[-1]
        review_boxes = driver.find_elements(By.CLASS_NAME, "jftiEf.fontBodyMedium")
        if last_review == review_boxes[-1]:
            try:
                print(len(list(driver.find_elements(By.CLASS_NAME, "BgrMEd.cYlvTc"))))
                driver.find_elements(By.CLASS_NAME, "BgrMEd.cYlvTc")[-2].click()
            except:
                pass
    time.sleep(10)
# Out:
#        price    year manufacturer                    model  condition  \
# 0      15000  2013.0         ford                f-150 xlt  excellent
# 1      19900  2004.0         ford          f250 super duty       good
# 2      14000  2012.0        honda                  odyssey  excellent
# 3      22500  2001.0         ford                     f450       good
# 4      15000  2017.0        dodge     charger rt 4dr sedan  excellent
# ...      ...     ...          ...                      ...        ...
# 80898  18000  2005.0    chevrolet    silverado 1500 lt 4x4  excellent
# 80899  18000  1990.0         jeep            gand wagoneer       good
# 80900   9800  1985.0       nissan  300zx coupe with t-tops   like new
# 80901   6800  1997.0       jaguar          xk8 convertible       good
# 80902      0  2018.0          ram                     2500  excellent
#
#          cylinders    fuel  odometer transmission drive         size  \
# ...

# %%
plt.figure(figsize=(12,10))
cor = df2.corr()
matrix = np.triu(cor)
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds, mask=matrix)
plt.show()

# %%
df3 =df2.sample(30000)
df3 = pd.get_dummies(df3)
df3
# Out:
#        price    year  odometer        lat        long  manufacturer_acura  \
# 58256   9495  2013.0  117003.0  40.733932  -82.791932                   0
# 39344  19990  2012.0  130740.0  47.901000  -97.044600                   0
# 73278      0  2015.0   76641.0  29.485474  -98.499295                   0
# 1999    3700  2009.0   92281.0  33.923500 -112.127900                   0
# 77087  17999  2019.0   16343.0  48.926705 -122.326180                   0
# ...      ...     ...       ...        ...         ...                 ...
# 37363   8995  2014.0   97069.0  42.689672  -83.393773                   0
# 21537   2995  2007.0  110000.0  30.375956  -84.292534                   0
# 67893  42950  2017.0   38737.0  43.556600  -96.802800                   0
# 45389   6999  2010.0     170.0  35.799154  -78.635413                   0
# 36179   7995  2006.0  189597.0  42.225504  -71.762086                   0
#
#        manufacturer_alfa-romeo  manufacturer_aston-martin  manufacturer_audi  \
# ...

# %%
X= df3.drop(["price"],axis =1)
y= df3["price"]
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25, random_state=7)

pipeline_lr=Pipeline([("scalar1",StandardScaler()),
                     ("lr_classifier",LinearRegression())])

pipeline_dt=Pipeline([("scalar2",StandardScaler()),
                     ("dt_classifier",DecisionTreeRegressor())])

pipeline_rf=Pipeline([("scalar3",StandardScaler()),
                     ("rf_classifier",RandomForestRegressor())])


pipeline_kn=Pipeline([("scalar4",StandardScaler()),
                     ("rf_classifier",KNeighborsRegressor())])


pipeline_xgb=Pipeline([("scalar5",StandardScaler()),
                     ("rf_classifier",XGBRegressor())])

# List of all the pipelines
pipelines = [pipeline_lr, pipeline_dt, pipeline_rf, pipeline_kn, pipeline_xgb]

# Dictionary of pipelines and model types for ease of reference
pipe_dict = {0: "LinearRegression", 1: "DecisionTree", 2: "RandomForest",3: "KNeighbors", 4: "XGBRegressor"}

# Fit the pipelines
for pipe in pipelines:
    pipe.fit(X_train, y_train)

# %%
cv_results_rms = []
for i, model in enumerate(pipelines):
    cv_score = cross_val_score(model, X_train,y_train,scoring="neg_root_mean_squared_error", cv=10)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# LinearRegression: -38800170619660066816.000000
# DecisionTree: -10603130.199227
# RandomForest: -9893903.182289
# C:\Users\moham\anaconda3\envs\ironhack\lib\site-packages\sklearn\model_selection\_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\moham\anaconda3\envs\ironhack\lib\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\moham\anaconda3\envs\ironhack\lib\site-packages\sklearn\metrics\_scorer.py", line 106, in __call__
#     score = scorer._score(cached_call, estimator, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\envs\ironhack\lib\site-packages\sklearn\metrics\_scorer.py", line 261, in _score
#     y_pred = method_caller(estimator, "predict", X)
# ...
